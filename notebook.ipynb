# %% [markdown]
# # Automated Pothole Detection | Omdena Kolkata Chapter
#
# _**Abinash Chetia**_

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # Model Training

# %% [markdown]
# # Model Deployment
